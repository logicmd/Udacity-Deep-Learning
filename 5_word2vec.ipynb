# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
#data [index]
#dictionary {word:index}
#reverse dictionary {index:word}
#count top {word:cnt}
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# zip(batch, labels) => (target, context) pairs

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
#tf.nn.softmax(tf.matmul(inputs, tf.transpose(weights)) + biases).

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
tmp_batch_size=8
batch_data, batch_labels = generate_batch(tmp_batch_size, num_skips, skip_window)
print (batch_data)
print (batch_data.reshape(tmp_batch_size,1).shape)
print (batch_labels)
print (batch_labels.reshape(tmp_batch_size).shape)
# Out:
# [   0    0   61   61 1639 1639    6    6]
# (8, 1)
# [[9466]
#  [  61]
#  [   0]
#  [1639]
#  [   6]
#  [  61]
#  [1639]
#  [6680]]
# (8,)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.316132
# Nearest to some: doctorate, grabbed, laughing, gould, traditionally, renders, caston, joanna,
# Nearest to b: vaccines, kimball, abernathy, depicted, archaeologists, pendleton, athenians, hilary,
# Nearest to after: contradictory, archimedean, tend, scholarly, slew, yat, janice, prolonging,
# Nearest to for: separatist, shocks, palmerston, pocketing, seasons, happily, dignity, incheon,
# Nearest to may: microprogramming, lavinia, valuation, kinross, sigismund, osnabr, hideki, achilles,
# Nearest to with: twinned, lucia, vga, kingfisher, tremor, bypassed, clodius, erewhon,
# Nearest to more: indicate, harps, busoni, lemnos, shrinking, belgrano, jesuit, steppe,
# Nearest to when: mutant, lms, cassady, exxon, flats, pembroke, methodius, wysiwyg,
# Nearest to by: determinant, possibly, throwers, raise, snake, deuteronomy, predominately, rodriguez,
# Nearest to if: ratios, cura, favor, bbci, cryobiology, xhosa, alvarado, jef,
# Nearest to d: advertised, lada, pike, swedes, abortions, magus, ldap, neuroimaging,
# Nearest to been: thursday, repulsion, anesthetics, kavina, raiders, hemp, mauritanian, wct,
# Nearest to five: undated, postumus, bayezid, chee, conjoined, widower, widest, nims,
# Nearest to war: wavelength, flawless, impression, cap, vertebra, surgically, viral, tennyson,
# Nearest to use: expose, mauchly, alkynes, nourished, plantagenet, borgir, fucking, juggalo,
# Nearest to of: humorously, mesons, leveled, physical, kevin, wartime, etudes, exons,
# Average loss at step 2000: 4.359935
# Average loss at step 4000: 3.865401
# Average loss at step 6000: 3.780617
# Average loss at step 8000: 3.682166
# Average loss at step 10000: 3.612667
# Nearest to some: many, pointe, grabbed, jewish, doctorate, featureless, laughing, greenville,
# Nearest to b: impaled, enthusiastically, depicted, d, hilary, gentle, archaeologists, pegs,
# Nearest to after: stellar, contradictory, renamo, ecosystems, slew, sandy, phrased, vast,
# Nearest to for: in, of, adolphus, separatist, sublimation, yy, experiencing, southend,
# Nearest to may: can, would, organisation, lavinia, drexler, see, vista, microprogramming,
# Nearest to with: in, eighteenth, on, syst, without, between, for, experiencing,
# Nearest to more: most, fredericksburg, busoni, jesuit, belgrano, gamete, deakin, technicians,
# Nearest to when: pembroke, cassady, hour, twists, keynesian, rhymes, mutant, itosu,
# Nearest to by: determinant, was, ddo, been, sup, transistor, from, cream,
# Nearest to if: although, sanctuaries, cura, cousin, bbci, facilitated, trakai, mechanically,
# Nearest to d: b, bolstering, decimals, foundered, swedes, lascaux, pitman, dogmatically,
# Nearest to been: kavina, by, ullmann, repulsion, cavalier, beaton, thursday, liners,
# Nearest to five: six, eight, nine, three, four, seven, zero, two,
# Nearest to war: melvins, setbacks, shorthand, cap, wavelength, rica, yakko, blanco,
# Nearest to use: borgir, quantized, expeditionary, moyne, spacious, plethora, alkynes, mauchly,
# Nearest to of: in, tutsis, eon, haliotis, humorously, for, tic, ltspkr,
# Average loss at step 12000: 3.599077
# Average loss at step 14000: 3.573486
# Average loss at step 16000: 3.407241
# Average loss at step 18000: 3.453752
# Average loss at step 20000: 3.538138
# Nearest to some: many, these, several, pointe, all, askari, other, hawthorne,
# Nearest to b: d, impaled, torment, french, enthusiastically, bolstering, toga, depicted,
# Nearest to after: before, renamo, when, friesian, stellar, shoulders, vivid, contradictory,
# Nearest to for: ahenobarbus, nominates, yy, at, and, by, of, or,
# Nearest to may: can, would, could, should, might, must, organisation, will,
# Nearest to with: at, eighteenth, in, and, by, between, like, experiencing,
# Nearest to more: less, most, gamete, larger, deakin, too, erect, detonator,
# Nearest to when: after, pembroke, hour, if, keynesian, flames, although, kzin,
# Nearest to by: through, be, determinant, with, were, is, chrysler, for,
# Nearest to if: although, facilitated, when, though, wynn, nuisance, however, ribozymes,
# Nearest to d: b, elegance, foundered, st, agis, iguana, pitman, superior,
# Nearest to been: become, be, was, were, kavina, by, ullmann, intersecting,
# Nearest to five: six, seven, four, three, eight, zero, two, nine,
# Nearest to war: melvins, shorthand, setbacks, cap, blanco, wavelength, grammer, yakko,
# Nearest to use: quantized, leiden, power, expeditionary, borgir, flipper, spacious, expose,
# Nearest to of: iic, backfired, tutsis, soma, for, in, ephemeris, main,
# Average loss at step 22000: 3.503556
# Average loss at step 24000: 3.497452
# Average loss at step 26000: 3.475565
# Average loss at step 28000: 3.480078
# Average loss at step 30000: 3.504545
# Nearest to some: many, these, several, certain, all, any, most, other,
# Nearest to b: d, bolstering, torment, impaled, oleg, labeled, paragliding, halls,
# Nearest to after: before, during, when, from, renamo, avidly, prolonging, since,
# Nearest to for: nominates, when, plowman, without, kyu, ahenobarbus, yy, multiplier,
# Nearest to may: can, would, could, should, might, must, will, cannot,
# Nearest to with: between, eighteenth, when, by, like, without, fuse, luk,
# Nearest to more: less, most, very, larger, persepolis, particularly, erect, mumps,
# Nearest to when: if, after, with, where, for, while, although, before,
# Nearest to by: determinant, with, ddo, was, were, been, from, in,
# Nearest to if: when, although, facilitated, though, where, is, ribozymes, cae,
# Nearest to d: b, elegance, verdean, bolstering, ventris, foundered, lascaux, agis,
# Nearest to been: become, was, be, were, kavina, by, already, gunners,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to war: shorthand, setbacks, escorted, blanco, complied, melvins, cap, tennyson,
# Nearest to use: aircraft, plethora, spacious, mention, support, mandy, moyne, flipper,
# Nearest to of: in, tutsis, from, beira, predating, multiprocessing, convenes, pressures,
# Average loss at step 32000: 3.502303
# Average loss at step 34000: 3.493089
# Average loss at step 36000: 3.450189
# Average loss at step 38000: 3.300796
# Average loss at step 40000: 3.424271
# Nearest to some: many, these, several, certain, any, most, modern, other,
# Nearest to b: d, UNK, kurf, megas, skins, impaled, k, oleg,
# Nearest to after: before, during, when, prolonging, renamo, from, with, valois,
# Nearest to for: plowman, in, musical, of, when, while, thrift, ahenobarbus,
# Nearest to may: can, would, could, might, should, will, must, cannot,
# Nearest to with: eighteenth, between, when, by, fuse, keeshond, after, luk,
# Nearest to more: less, most, larger, very, scandalous, smaller, too, longer,
# Nearest to when: if, before, while, where, during, with, after, until,
# Nearest to by: with, from, limiting, cream, filamentous, asphyxiation, as, wit,
# Nearest to if: when, where, although, facilitated, though, so, can, nintendo,
# Nearest to d: b, elegance, lascaux, kazimierz, foundered, verdean, ventris, abortions,
# Nearest to been: become, be, was, had, were, being, already, widened,
# Nearest to five: seven, six, three, four, eight, zero, nine, two,
# Nearest to war: setbacks, escorted, melvins, cap, shorthand, impression, tennyson, firm,
# Nearest to use: plethora, support, malayalam, aircraft, nearer, spacious, moyne, coa,
# Nearest to of: in, from, humorously, mcneil, for, predating, witold, richness,
# Average loss at step 42000: 3.434687
# Average loss at step 44000: 3.450034
# Average loss at step 46000: 3.448822
# Average loss at step 48000: 3.352841
# Average loss at step 50000: 3.381681
# Nearest to some: many, several, these, both, certain, various, any, all,
# Nearest to b: d, k, skins, mays, megas, kurf, trot, ata,
# Nearest to after: before, during, when, while, from, at, through, renamo,
# Nearest to for: plowman, ahenobarbus, nominates, yy, including, regarding, without, untouchable,
# Nearest to may: can, would, should, could, might, will, must, cannot,
# Nearest to with: between, by, bypassed, experiencing, luk, portman, fuse, wheel,
# Nearest to more: less, most, very, larger, highly, longer, abuser, relatively,
# Nearest to when: while, if, after, before, where, during, until, hour,
# Nearest to by: through, was, subconscious, wit, determinant, with, illa, knight,
# Nearest to if: when, though, where, although, so, before, nintendo, while,
# Nearest to d: b, elegance, lascaux, ventris, r, p, e, paragliding,
# Nearest to been: become, was, be, already, were, widened, had, witchcraft,
# Nearest to five: four, six, eight, seven, zero, three, nine, two,
# Nearest to war: escorted, cap, firm, setbacks, pkn, wavelength, melvins, impression,
# Nearest to use: support, nearer, plethora, mention, coa, mandy, int, spouses,
# Nearest to of: in, including, tigray, and, beano, ik, syst, aw,
# Average loss at step 52000: 3.433413
# Average loss at step 54000: 3.430676
# Average loss at step 56000: 3.434426
# Average loss at step 58000: 3.395066
# Average loss at step 60000: 3.392793
# Nearest to some: many, several, these, various, certain, any, all, different,
# Nearest to b: d, k, kurf, megas, c, skins, z, iguana,
# Nearest to after: before, during, when, through, while, following, since, respective,
# Nearest to for: of, including, southend, ahenobarbus, bonobo, reconfigurable, normality, arrangers,
# Nearest to may: can, would, could, might, should, will, must, cannot,
# Nearest to with: between, luk, eighteenth, when, in, by, bypassed, suras,
# Nearest to more: less, most, very, larger, longer, highly, abuser, greater,
# Nearest to when: if, while, after, before, where, during, although, though,
# Nearest to by: through, with, cart, resented, was, wit, cetacean, filamentous,
# Nearest to if: when, where, though, before, although, so, since, could,
# Nearest to d: b, elegance, rivest, h, ventris, r, lascaux, bhfiann,
# Nearest to been: become, be, was, already, were, dimensionality, had, being,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to war: escorted, pkn, cap, setbacks, impression, shorthand, firm, flawless,
# Nearest to use: support, plethora, nearer, mention, spouses, coa, biased, phylogeny,
# Nearest to of: in, for, humorously, same, although, from, include, multiprocessing,
# Average loss at step 62000: 3.239303
# Average loss at step 64000: 3.250941
# Average loss at step 66000: 3.404811
# Average loss at step 68000: 3.395340
# Average loss at step 70000: 3.356611
# Nearest to some: many, several, these, most, various, all, any, certain,
# Nearest to b: d, r, k, kurf, h, z, f, megas,
# Nearest to after: before, during, when, while, if, loyalist, until, consumes,
# Nearest to for: in, ahenobarbus, including, without, plowman, mandaic, multiplier, reconfigurable,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to with: between, bypassed, when, luk, lumber, without, like, by,
# Nearest to more: less, most, larger, very, longer, rather, highly, hultsfred,
# Nearest to when: if, before, after, while, where, however, though, during,
# Nearest to by: through, from, be, wit, cetacean, architectures, was, as,
# Nearest to if: when, though, where, before, after, although, so, why,
# Nearest to d: b, elegance, r, lascaux, ventris, h, bhfiann, diplomas,
# Nearest to been: become, be, was, already, had, were, come, dimensionality,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to war: escorted, pkn, firm, impression, monotheists, setbacks, cap, flawless,
# Nearest to use: support, nearer, plethora, coa, mention, most, mean, novgorod,
# Nearest to of: including, include, and, filamentous, in, humorously, chicano, swimmers,
# Average loss at step 72000: 3.374349
# Average loss at step 74000: 3.348582
# Average loss at step 76000: 3.309273
# Average loss at step 78000: 3.348112
# Average loss at step 80000: 3.374634
# Nearest to some: many, several, various, these, any, certain, most, both,
# Nearest to b: d, megas, c, h, r, p, z, kurf,
# Nearest to after: before, during, when, while, despite, following, consumes, if,
# Nearest to for: normality, nominates, without, adolphus, albigensians, ahenobarbus, renewable, bouvet,
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to with: between, luk, or, in, wheel, by, uneven, when,
# Nearest to more: less, most, very, larger, longer, rather, hultsfred, highly,
# Nearest to when: before, if, after, during, while, though, however, where,
# Nearest to by: through, with, wrought, during, wit, from, using, when,
# Nearest to if: when, though, before, where, guano, so, because, although,
# Nearest to d: b, bhfiann, g, h, elegance, z, lascaux, r,
# Nearest to been: become, be, was, already, were, had, come, fallen,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to war: escorted, pkn, firm, monotheists, setbacks, impression, flawless, contempt,
# Nearest to use: support, nearer, plethora, deeds, phylogeny, because, mention, moyne,
# Nearest to of: in, syst, including, witold, tigray, harpercollins, tartu, abernathy,
# Average loss at step 82000: 3.406172
# Average loss at step 84000: 3.406848
# Average loss at step 86000: 3.387103
# Average loss at step 88000: 3.353745
# Average loss at step 90000: 3.363356
# Nearest to some: many, several, these, most, any, certain, this, various,
# Nearest to b: d, h, k, megas, z, r, kurf, c,
# Nearest to after: before, during, when, while, if, without, until, despite,
# Nearest to for: including, of, aeons, nominates, plowman, aalto, ahenobarbus, by,
# Nearest to may: can, could, would, must, might, should, will, cannot,
# Nearest to with: between, luk, without, heckler, in, eighteenth, fuse, by,
# Nearest to more: less, very, larger, most, longer, rather, hultsfred, highly,
# Nearest to when: before, if, after, while, where, during, though, because,
# Nearest to by: through, when, without, filamentous, wit, from, respectable, for,
# Nearest to if: when, though, before, where, follows, so, after, because,
# Nearest to d: b, elegance, rivest, r, h, bhfiann, hava, lascaux,
# Nearest to been: become, be, already, was, had, were, being, fallen,
# Nearest to five: seven, eight, four, six, three, nine, zero, two,
# Nearest to war: impression, escorted, firm, monotheists, pkn, silmarillion, contempt, flawless,
# Nearest to use: support, nearer, plethora, list, most, because, novgorod, deeds,
# Nearest to of: including, for, include, during, following, definiteness, in, predating,
# Average loss at step 92000: 3.399337
# Average loss at step 94000: 3.250532
# Average loss at step 96000: 3.363914
# Average loss at step 98000: 3.245473
# Average loss at step 100000: 3.356756
# Nearest to some: many, several, these, any, certain, various, all, each,
# Nearest to b: d, pegs, fisher, labeled, wayne, kopp, homeopaths, estonia,
# Nearest to after: before, during, when, while, without, through, although, despite,
# Nearest to for: without, when, if, nominates, while, plowman, before, in,
# Nearest to may: can, could, must, should, would, might, will, cannot,
# Nearest to with: between, luk, including, lippincott, in, fuse, codons, portman,
# Nearest to more: less, most, very, larger, longer, particularly, highly, quite,
# Nearest to when: if, before, while, though, after, where, although, during,
# Nearest to by: through, when, been, cetacean, without, wit, pickled, during,
# Nearest to if: when, though, where, before, follows, for, because, after,
# Nearest to d: b, q, flagellum, bolstering, paragliding, h, p, gourd,
# Nearest to been: become, be, already, was, by, desserts, lep, nom,
# Nearest to five: seven, four, eight, six, three, zero, nine, two,
# Nearest to war: escorted, pkn, impression, monotheists, firm, setbacks, wars, ridicule,
# Nearest to use: support, nearer, plethora, most, deeds, sizes, coa, mention,
# Nearest to of: in, including, tigray, tutsis, entire, original, and, kinematic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_CBOW_batch(batch_size, num_skips, skip_window):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    return batch_labels.reshape(batch_size), batch_data.reshape(batch_size,1)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session_CBOW:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_CBOW_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session_CBOW.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.428860
# Nearest to some: ashley, holders, lint, slowly, squire, goldstein, nighttime, our,
# Nearest to b: dolls, moltke, reassessment, obrzeg, ueshiba, parents, jahn, university,
# Nearest to after: cyan, amplifies, typographical, triglycerides, huntingdon, propane, thulsa, resent,
# Nearest to for: annul, aromas, boasts, normal, naming, fayette, formulate, lassa,
# Nearest to may: lines, parcham, meals, rojas, franck, gabon, calif, chadic,
# Nearest to with: huffman, gb, nicolai, manhunter, sudan, methane, macron, sc,
# Nearest to more: respond, cut, deum, manufacturer, aside, every, valve, paton,
# Nearest to when: mews, taking, ostwald, tabby, bollywood, tutored, diagram, xxxviii,
# Nearest to by: fm, youngsters, discover, slovenia, utrecht, lan, defendant, narration,
# Nearest to if: eclac, emile, bayezid, presbyter, manufacturing, rebels, castilla, olden,
# Nearest to d: jingles, genre, oxidising, ballets, limestone, growths, plosive, toulon,
# Nearest to been: mb, adultery, rubenstein, dar, carney, dishonesty, alexandrina, writeups,
# Nearest to five: warrior, amides, degas, fitna, blonde, fulfilment, waffen, solon,
# Nearest to war: replicated, kazakhs, hindenburg, dirac, identical, indexing, dat, fathoms,
# Nearest to use: parmenides, wants, aleph, hides, brigades, believe, germination, unload,
# Nearest to of: mauritian, contrary, interaction, luening, chives, philadelphia, jefferson, strangled,
# Average loss at step 2000: 4.369260
# Average loss at step 4000: 3.868966
# Average loss at step 6000: 3.797183
# Average loss at step 8000: 3.755916
# Average loss at step 10000: 3.618753
# Nearest to some: our, many, other, such, transporters, weekend, azzam, millennialism,
# Nearest to b: moltke, footballer, ueshiba, salamis, dolls, reassessment, domingue, eleusinian,
# Nearest to after: typographical, biochemistry, during, hancock, corrected, by, cypriots, dili,
# Nearest to for: with, and, in, of, to, hormones, ahasuerus, or,
# Nearest to may: will, would, can, could, lines, renown, mugwort, tides,
# Nearest to with: by, in, for, gb, on, anecdotes, sudan, neutron,
# Nearest to more: hellbender, respond, incan, swords, scandinavian, mesolithic, existent, every,
# Nearest to when: where, appropriated, midfield, first, ostwald, tutored, pineapple, diversified,
# Nearest to by: with, was, in, be, at, and, nevertheless, from,
# Nearest to if: priesthood, protozoa, antigua, will, bankrupted, deepening, thus, but,
# Nearest to d: jingles, seem, genre, growths, previews, passengers, limestone, ballets,
# Nearest to been: be, pizzicato, humanity, serene, watergate, sorority, chapultepec, boland,
# Nearest to five: eight, four, seven, six, three, nine, zero, two,
# Nearest to war: replicated, hindenburg, dat, kazakhs, moira, dirac, princip, modernized,
# Nearest to use: woefully, believe, recharge, hides, especial, doyle, entheogen, aleph,
# Nearest to of: in, for, and, s, entire, enchantments, disavowed, macht,
# Average loss at step 12000: 3.578152
# Average loss at step 14000: 3.619936
# Average loss at step 16000: 3.583918
# Average loss at step 18000: 3.568976
# Average loss at step 20000: 3.544386
# Nearest to some: many, these, our, other, several, their, goto, such,
# Nearest to b: footballer, d, n, autobahn, domingue, dolls, slovenia, doppelbock,
# Nearest to after: during, before, kale, through, by, biochemistry, larousse, when,
# Nearest to for: to, in, with, by, ahasuerus, gretchen, normal, svenska,
# Nearest to may: can, would, will, could, should, might, aleksandr, zaragoza,
# Nearest to with: between, in, robertson, anecdotes, gb, for, through, single,
# Nearest to more: most, less, respond, very, mesolithic, existent, casualties, watergate,
# Nearest to when: where, if, preview, though, before, delight, midfield, after,
# Nearest to by: was, be, quadriceps, from, hindu, neuropsychological, martialed, been,
# Nearest to if: will, when, though, protozoa, priesthood, before, antigua, above,
# Nearest to d: b, jingles, sp, growths, passengers, bosman, previews, genre,
# Nearest to been: be, become, pizzicato, was, by, humanity, boland, were,
# Nearest to five: seven, six, eight, four, nine, zero, three, two,
# Nearest to war: replicated, moira, princip, como, penh, dirac, corrections, hindenburg,
# Nearest to use: woefully, doyle, especial, recharge, incidentally, entheogen, wants, believe,
# Nearest to of: and, same, in, hallstatt, entire, philadelphia, gardening, enchantments,
# Average loss at step 22000: 3.520301
# Average loss at step 24000: 3.444200
# Average loss at step 26000: 3.413539
# Average loss at step 28000: 3.474379
# Average loss at step 30000: 3.402226
# Nearest to some: many, these, several, other, themselves, our, their, slavs,
# Nearest to b: d, footballer, clippers, slovenia, turret, moltke, irresponsibility, electronica,
# Nearest to after: during, before, when, kale, judaea, including, as, erin,
# Nearest to for: hormones, in, drumlins, ahasuerus, maximilien, coulomb, including, normal,
# Nearest to may: can, will, would, could, should, might, must, cannot,
# Nearest to with: between, in, without, by, una, gb, tunisia, at,
# Nearest to more: less, most, very, storey, commissar, respond, cut, mesolithic,
# Nearest to when: if, where, though, before, preview, after, as, although,
# Nearest to by: be, as, was, with, quadriceps, being, hindu, neuropsychological,
# Nearest to if: when, where, though, before, is, will, because, makes,
# Nearest to d: b, jingles, mariana, seem, genre, sp, triple, passengers,
# Nearest to been: become, be, were, had, chapultepec, controllable, braintree, pizzicato,
# Nearest to five: seven, six, four, eight, nine, zero, three, two,
# Nearest to war: replicated, moira, princip, dirac, kitts, penh, corrections, whitacre,
# Nearest to use: woefully, wants, recharge, doyle, entheogen, incidentally, believe, especial,
# Nearest to of: in, and, including, enchantments, gardening, naphtali, same, while,
# Average loss at step 32000: 3.418766
# Average loss at step 34000: 3.434969
# Average loss at step 36000: 3.370715
# Average loss at step 38000: 3.492115
# Average loss at step 40000: 3.445256
# Nearest to some: many, these, several, other, both, themselves, all, their,
# Nearest to b: d, domingue, footballer, turret, ueshiba, slovenia, guam, snowball,
# Nearest to after: before, during, when, erin, through, thermometers, until, template,
# Nearest to for: drumlins, in, including, without, lassa, barthes, sofia, using,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to with: between, without, gb, by, using, when, into, transcript,
# Nearest to more: less, very, most, too, greater, cut, smaller, commissar,
# Nearest to when: if, before, although, because, where, after, while, but,
# Nearest to by: connectionless, with, robertson, been, talked, neuropsychological, be, maffei,
# Nearest to if: when, though, although, where, before, because, is, then,
# Nearest to d: b, growths, rollins, convolutions, pierce, mariana, sp, seem,
# Nearest to been: become, be, was, were, controllable, braintree, negatively, stepwise,
# Nearest to five: four, six, zero, seven, two, eight, three, nine,
# Nearest to war: replicated, moira, prussia, bavarian, union, princip, penh, verge,
# Nearest to use: woefully, leading, wants, entheogen, incidentally, kristeva, unload, especial,
# Nearest to of: nsdap, including, in, hallstatt, coiled, greeting, monogamy, while,
# Average loss at step 42000: 3.421502
# Average loss at step 44000: 3.280263
# Average loss at step 46000: 3.406468
# Average loss at step 48000: 3.438207
# Average loss at step 50000: 3.428582
# Nearest to some: many, several, these, any, our, various, most, their,
# Nearest to b: d, domingue, n, c, autobahn, f, turret, rockingham,
# Nearest to after: before, during, when, for, until, through, from, last,
# Nearest to for: after, when, during, of, wilmot, drumlins, maximilien, while,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to with: between, in, without, and, by, roller, fasces, like,
# Nearest to more: less, very, most, rather, smaller, too, storey, extremely,
# Nearest to when: if, before, although, after, where, while, during, because,
# Nearest to by: neuropsychological, was, from, when, without, digestive, during, maffei,
# Nearest to if: when, where, though, although, since, then, before, because,
# Nearest to d: b, barbed, c, pierce, growths, martha, f, bosman,
# Nearest to been: become, be, was, were, had, controllable, braintree, negatively,
# Nearest to five: four, six, seven, three, eight, two, nine, zero,
# Nearest to war: replicated, prussia, moira, princip, bavarian, government, restless, lexicographic,
# Nearest to use: woefully, entheogen, leading, kristeva, wants, incidentally, invalidated, unload,
# Nearest to of: in, for, while, during, nsdap, and, with, s,
# Average loss at step 52000: 3.456679
# Average loss at step 54000: 3.431785
# Average loss at step 56000: 3.406514
# Average loss at step 58000: 3.276605
# Average loss at step 60000: 3.383471
# Nearest to some: many, several, these, all, any, various, both, those,
# Nearest to b: d, n, domingue, f, c, autobahn, k, h,
# Nearest to after: before, during, when, under, while, until, last, since,
# Nearest to for: including, ahasuerus, without, while, after, maximilien, drumlins, enigmas,
# Nearest to may: can, would, could, should, will, might, must, cannot,
# Nearest to with: between, without, gila, centrum, using, fasces, among, courier,
# Nearest to more: less, very, most, rather, smaller, extremely, greater, too,
# Nearest to when: if, while, although, before, where, after, because, during,
# Nearest to by: without, was, greasy, as, from, during, smallholders, feeders,
# Nearest to if: when, though, where, although, is, think, must, gently,
# Nearest to d: b, barbed, pierce, c, sp, convolutions, martha, r,
# Nearest to been: become, be, was, were, controllable, had, braintree, marshals,
# Nearest to five: eight, six, four, nine, seven, three, two, zero,
# Nearest to war: replicated, prussia, verge, lexicographic, moira, restless, bavarian, princip,
# Nearest to use: woefully, wants, entheogen, cause, sampled, usage, monarchists, kristeva,
# Nearest to of: in, and, including, s, during, for, against, consecrations,
# Average loss at step 62000: 3.440838
# Average loss at step 64000: 3.357667
# Average loss at step 66000: 3.341417
# Average loss at step 68000: 3.385126
# Average loss at step 70000: 3.369801
# Nearest to some: many, several, these, any, both, various, those, other,
# Nearest to b: d, n, f, c, r, v, j, canso,
# Nearest to after: before, during, while, when, following, under, despite, lagi,
# Nearest to for: sofia, without, when, after, by, cuyp, drumlins, although,
# Nearest to may: can, would, should, could, will, might, must, cannot,
# Nearest to with: between, among, using, without, by, against, transcript, menachem,
# Nearest to more: less, very, most, smaller, extremely, too, rather, greater,
# Nearest to when: if, while, although, where, before, though, because, after,
# Nearest to by: through, without, was, with, throughout, for, neuropsychological, quadriceps,
# Nearest to if: when, though, where, although, before, while, because, will,
# Nearest to d: b, pierce, barbed, c, martha, passengers, growths, convolutions,
# Nearest to been: become, be, controllable, was, braintree, since, ascetics, were,
# Nearest to five: four, six, seven, eight, nine, zero, three, two,
# Nearest to war: prussia, verge, moira, princip, bavarian, replicated, indexing, pittsburg,
# Nearest to use: woefully, cause, sampled, wants, incidentally, invalidated, solve, kristeva,
# Nearest to of: including, quebecers, in, assaulting, comparative, madonna, gloster, rarefied,
# Average loss at step 72000: 3.402972
# Average loss at step 74000: 3.386321
# Average loss at step 76000: 3.352715
# Average loss at step 78000: 3.233480
# Average loss at step 80000: 3.379348
# Nearest to some: many, several, these, any, both, this, most, various,
# Nearest to b: f, d, n, c, y, domingue, x, australopithecines,
# Nearest to after: before, during, when, while, following, since, until, despite,
# Nearest to for: when, if, without, sofia, while, maximilien, coulomb, drumlins,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to with: between, without, when, among, using, gb, icann, roller,
# Nearest to more: less, very, most, too, extremely, smaller, greater, rather,
# Nearest to when: if, although, while, where, though, because, before, after,
# Nearest to by: through, without, neuropsychological, digestive, is, as, ridinghood, on,
# Nearest to if: when, where, though, then, although, for, before, goetz,
# Nearest to d: b, pierce, barbed, parodying, vascular, martha, italia, reinstatement,
# Nearest to been: become, be, controllable, braintree, already, were, recently, ascetics,
# Nearest to five: seven, four, six, eight, zero, three, nine, two,
# Nearest to war: moira, verge, prussia, kazakhstan, actuarial, bavarian, princip, closes,
# Nearest to use: woefully, usage, entheogen, sampled, connect, awkward, solve, because,
# Nearest to of: in, and, rarefied, nsdap, for, including, macroscopic, same,
# Average loss at step 82000: 3.296792
# Average loss at step 84000: 3.333246
# Average loss at step 86000: 3.345009
# Average loss at step 88000: 3.322203
# Average loss at step 90000: 3.237981
# Nearest to some: many, several, these, any, various, numerous, all, certain,
# Nearest to b: d, clippers, footballer, and, weld, n, centennial, guam,
# Nearest to after: before, during, when, following, lacked, until, while, since,
# Nearest to for: drumlins, as, after, traitor, eos, culinary, coulomb, spinster,
# Nearest to may: could, can, will, should, would, must, might, cannot,
# Nearest to with: between, by, in, through, robertson, among, iaea, into,
# Nearest to more: less, very, most, smaller, greater, too, extremely, layout,
# Nearest to when: if, while, although, though, after, where, before, during,
# Nearest to by: through, robertson, with, when, dewitt, insulator, maffei, digestive,
# Nearest to if: though, when, before, although, where, does, since, did,
# Nearest to d: b, one, and, pierce, parodying, barbed, american, marshall,
# Nearest to been: become, be, was, controllable, braintree, already, had, ascetics,
# Nearest to five: seven, four, three, six, eight, nine, zero, two,
# Nearest to war: moira, prussia, verge, princip, closes, lexicographic, actuarial, leap,
# Nearest to use: usage, threads, awkward, cause, list, entheogen, connect, incidentally,
# Nearest to of: in, and, beverley, aphelion, including, confuses, citadels, s,
# Average loss at step 92000: 2.733774
# Average loss at step 94000: 3.107995
# Average loss at step 96000: 3.065437
# Average loss at step 98000: 3.219894
# Average loss at step 100000: 3.275333
# Nearest to some: many, several, these, any, various, numerous, this, both,
# Nearest to b: d, shapeshifting, turret, footballer, sg, lande, psc, massage,
# Nearest to after: before, during, when, while, lacked, following, despite, though,
# Nearest to for: without, by, of, eos, including, after, cuyp, boasts,
# Nearest to may: should, can, would, could, will, must, might, cannot,
# Nearest to with: between, through, in, by, among, gb, using, roller,
# Nearest to more: less, most, very, too, smaller, greater, extremely, longer,
# Nearest to when: while, although, though, if, where, after, before, however,
# Nearest to by: through, without, for, against, greasy, with, neuropsychological, credits,
# Nearest to if: when, though, however, where, before, did, although, but,
# Nearest to d: b, convolutions, dani, jacky, ueshiba, evacuation, previews, parodying,
# Nearest to been: become, be, was, already, controllable, previously, were, ascetics,
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Nearest to war: moira, prussia, princip, lexicographic, verge, closes, mist, yugoslavia,
# Nearest to use: usage, cause, support, awkward, yeni, list, sense, solve,
# Nearest to of: for, and, minutemen, prophetic, without, in, concerning, entire,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
